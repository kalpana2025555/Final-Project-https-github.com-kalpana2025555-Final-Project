# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the Haar Cascade XML file for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
def detect_faces(image_path):
    # Read the image
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Draw rectangles around detected faces
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Convert BGR to RGB for displaying with matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.show()

# Test with an image
detect_faces("sample_image.jpg")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 20
#      17     plt.show()
#      19 # Test with an image
# ---> 20 detect_faces("sample_image.jpg")
#
# Cell In[3], line 4, in detect_faces(image_path)
#       1 def detect_faces(image_path):
#       2     # Read the image
#       3     img = cv2.imread(image_path)
# ----> 4     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       6     # Detect faces
#       7     faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
import os

image_path = "C:\\Users\\kalpana\\Downloads\\images-20250217T092357Z-001.zip"

# Check if the file exists
if not os.path.exists(image_path):
    print("Error: Image file not found!")
else:
    img = cv2.imread(image_path)
    if img is None:
        print("Error: Failed to read the image!")
    else:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        print("Image loaded successfully!")
# Out:
# Error: Failed to read the image!

# %%
import cv2
import os

# Use the absolute path to the image
image_path = r"C:\\Users\\kalpana\\Downloads\\images-20250217T092357Z-001.zip"

# Check if the file exists
if not os.path.exists(image_path):
    print("Error: Image file not found!")
else:
    img = cv2.imread(image_path)
    if img is None:
        print("Error: Failed to read the image!")
    else:
        print("Image loaded successfully!")
# Out:
# Error: Failed to read the image!

# %%
import zipfile

zip_path = r"C:\Users\kalpana\Downloads\images-20250217T092357Z-001.zip"
extract_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)
    print("ZIP file extracted successfully!")

# Get the list of extracted files
import os
image_files = [f for f in os.listdir(extract_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]
print("Extracted images:", image_files)
# Out:
# ZIP file extracted successfully!
# Extracted images: []

# %%
import cv2
import os

# Choose an extracted image
image_path = os.path.join(extract_folder, image_files[0])  # First image in the list

# Check if file exists
if not os.path.exists(image_path):
    print("Error: Extracted image not found!")
else:
    img = cv2.imread(image_path)
    if img is None:
        print("Error: Failed to read the extracted image!")
    else:
        print("Success: Image loaded successfully!")
        cv2.imshow("Extracted Image", img)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 5
#       2 import os
#       4 # Choose an extracted image
# ----> 5 image_path = os.path.join(extract_folder, image_files[0])  # First image in the list
#       7 # Check if file exists
#       8 if not os.path.exists(image_path):
#
# IndexError: list index out of range

# %%
import os

extract_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# List all extracted files
extracted_files = os.listdir(extract_folder)
print("Extracted Files:", extracted_files)
# Out:
# Extracted Files: ['images']

# %%
import zipfile

zip_path = r"C:\Users\kalpana\Downloads\images-20250217T092357Z-001.zip"
extract_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)
    print("ZIP file extracted successfully!")
# Out:
# ZIP file extracted successfully!

# %%
# Check extracted images
image_files = [f for f in os.listdir(extract_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
print("Image files found:", image_files)
# Out:
# Image files found: []

# %%
if not image_files:
    print("Error: No image files found in the extracted folder!")
else:
    image_path = os.path.join(extract_folder, image_files[0])  # First image
    print("Using image:", image_path)
# Out:
# Error: No image files found in the extracted folder!

# %%
import os

extract_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# List all extracted files and folders
extracted_items = os.listdir(extract_folder)
print("Extracted Items:", extracted_items)
# Out:
# Extracted Items: ['images']

# %%
import os

extract_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# Find subfolders
subfolders = [f for f in os.listdir(extract_folder) if os.path.isdir(os.path.join(extract_folder, f))]
print("Subfolders:", subfolders)

# If a subfolder exists, check inside it
if subfolders:
    subfolder_path = os.path.join(extract_folder, subfolders[0])  # First subfolder
    image_files = [f for f in os.listdir(subfolder_path) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
    print("Image files found in subfolder:", image_files)

    if image_files:
        image_path = os.path.join(subfolder_path, image_files[0])  # First image
        print("Using image:", image_path)
    else:
        print("Error: No images found inside subfolder!")
else:
    print("No subfolders found. Checking the main extracted folder...")
# Out:
# Subfolders: ['images']
# ...

# %%
import zipfile

zip_path = r"C:\Users\kalpana\Downloads\images-20250217T092357Z-001.zip"
extract_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# Re-extract ZIP
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)
    print("ZIP extracted successfully!")

# Check again
extracted_items = os.listdir(extract_folder)
print("Extracted Items:", extracted_items)
# Out:
# ZIP extracted successfully!
# Extracted Items: ['images']

# %%
# !pip install opencv-python numpy matplotlib

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Path to the extracted images folder
extract_folder = r"C:\Users\kalpana\Downloads\extracted_images"  # Update this if needed

# Load the pre-trained Haar Cascade classifier for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def detect_faces_in_image(image_path):
    # Load the image
    img = cv2.imread(image_path)
    
    if img is None:
        print(f"Error: Failed to read image {image_path}")
        return

    # Convert to grayscale for face detection
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces in the image
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Draw rectangles around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
    
    # Convert BGR to RGB for displaying with matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the image with detected faces
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.show()

def process_images_in_folder(folder_path):
    # List all image files in the folder
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
    
    if not image_files:
        print("No images found in the folder!")
        return
    
    # Loop through each image and detect faces
    for image_file in image_files:
        image_path = os.path.join(folder_path, image_file)
        print(f"Processing image: {image_file}")
        detect_faces_in_image(image_path)

# Process all images in the extracted folder
process_images_in_folder(extract_folder)
# Out:
# No images found in the folder!

# %%
import os

extract_folder = r"C:\Users\kalpana\Downloads\extracted_images"  # Update the path if needed

# List all files and folders in the extracted folder
extracted_items = os.listdir(extract_folder)
print("Extracted Items:", extracted_items)

# Check if any subfolders exist
subfolders = [f for f in extracted_items if os.path.isdir(os.path.join(extract_folder, f))]
print("Subfolders:", subfolders)
# Out:
# Extracted Items: ['images']
# Subfolders: ['images']

# %%
# If there are subfolders, check for images inside them
def find_images_in_subfolders(folder_path):
    image_files = []
    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)
        if os.path.isdir(subfolder_path):
            # Check for images in the subfolder
            image_files.extend([f for f in os.listdir(subfolder_path) if f.lower().endswith(('.jpg', '.png', '.jpeg'))])
    return image_files

# Get images from subfolders (if any)
image_files = find_images_in_subfolders(extract_folder)

# If no images found, print message
if not image_files:
    print("Error: No image files found!")
else:
    print("Image files found:", image_files)
# Out:
# Image files found: ['00000003.jpg', '00000004.jpg', '00000005.jpg', '00000006.jpg', '00000008.jpg', '00000011.jpg', '00000012.jpg', '00000015.jpg', '00000018.jpg', '00000020.jpg', '00000022.jpg', '00000023.jpg', '00000024.jpg', '00000026.jpg', '00000031.jpg', '00000032.jpg', '00000041.jpg', '00000044.jpg', '00000045.jpg', '00000047.jpg', '00000050.jpg', '00000051.jpg', '00000055.jpg', '00000058.jpg', '00000061.jpg', '00000067.jpg', '00000068.jpg', '00000069.jpg', '00000072.jpg', '00000074.jpg', '00000075.jpg', '00000077.jpg', '00000082.jpg', '00000085.jpg', '00000086.jpg', '00000087.jpg', '00000088.jpg', '00000089.jpg', '00000091.jpg', '00000094.jpg', '00000095.jpg', '00000097.jpg', '00000099.jpg', '00000100.jpg', '00000103.jpg', '00000104.jpg', '00000105.jpg', '00000107.jpg', '00000110.jpg', '00000114.jpg', '00000115.jpg', '00000118.jpg', '00000119.jpg', '00000120.jpg', '00000123.jpg', '00000127.jpg', '00000128.jpg', '00000129.jpg', '00000135.jpg', '00000136.jpg', '00000137.jpg', '0
# ...

# %%
# Include more image extensions in the check
image_files = [f for f in os.listdir(extract_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg', '.bmp', '.tiff'))]

print("Image files found:", image_files)
# Out:
# Image files found: []

# %%
import zipfile

zip_path = r"C:\Users\kalpana\Downloads\images-20250217T092357Z-001.zip"
extract_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# List contents of the ZIP file without extracting
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_contents = zip_ref.namelist()

print("ZIP Contents:", zip_contents)
# Out:
# ZIP Contents: ['images/00003507.jpg', 'images/00003486.jpg', 'images/00003473.jpg', 'images/00003475.jpg', 'images/00003502.jpg', 'images/00003489.jpg', 'images/00003482.jpg', 'images/00003477.jpg', 'images/00003471.jpg', 'images/00003510.jpg', 'images/00003504.jpg', 'images/00003514.jpg', 'images/00003478.jpg', 'images/00003505.jpg', 'images/00003492.jpg', 'images/00003476.jpg', 'images/00003501.jpg', 'images/00003453.jpg', 'images/00003449.jpg', 'images/00003484.jpg', 'images/00003487.jpg', 'images/00003450.jpg', 'images/00003513.jpg', 'images/00003497.jpg', 'images/00003483.jpg', 'images/00003447.jpg', 'images/00003459.jpg', 'images/00003456.jpg', 'images/00003444.jpg', 'images/00003402.jpg', 'images/00003454.jpg', 'images/00003517.jpg', 'images/00003480.jpg', 'images/00003457.jpg', 'images/00003472.jpg', 'images/00003442.jpg', 'images/00003439.jpg', 'images/00003460.jpg', 'images/00003496.jpg', 'images/00003427.jpg', 'images/00003467.jpg', 'images/00003500.jpg', 'images/00003498.
# ...

# %%
import zipfile
import os

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)
    print("ZIP file extracted!")

# List all files in the extracted folder (including subfolders)
def find_images_in_folder(folder_path):
    image_files = []
    for root, dirs, files in os.walk(folder_path):  # Traverse subfolders
        for file in files:
            if file.lower().endswith(('.jpg', '.png', '.jpeg', '.bmp', '.tiff')):
                image_files.append(os.path.join(root, file))
    return image_files

# Find images in all extracted subfolders
image_files = find_images_in_folder(extract_folder)

print("Image files found:", image_files)
# Out:
# ZIP file extracted!
# ...

# %%
image_files = [f for f in os.listdir(extract_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg', '.bmp', '.tiff', '.webp', '.gif'))]

# %%
import zipfile
import os

# Path to your ZIP file and extract folder
zip_path = r"C:\Users\kalpana\Downloads\images-20250217T092357Z-001.zip"
extract_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)
    print(f"ZIP file extracted to {extract_folder}")

# List all files recursively in the extracted folder
def list_all_files_in_folder(folder_path):
    file_list = []
    for root, dirs, files in os.walk(folder_path):  # Traverse all folders and subfolders
        for file in files:
            file_list.append(os.path.join(root, file))
    return file_list

# Get all files in the extracted folder
all_files = list_all_files_in_folder(extract_folder)

# Print the full file paths
print("All files in the extracted folder:", all_files)

# Optionally, check if any files are images by extension
image_files = [file for file in all_files if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]
print("Image files found:", image_files)
# Out:
# ZIP file extracted to C:\Users\kalpana\Downloads\extracted_images
# ...

# %%
import os

# Folder containing images
folder_path = r"C:\\Users\\kalpana\\Downloads\\extracted_images"  # Update with your path

# List all image files in the folder
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))]

# Detect faces in each image
for image_file in image_files:
    image_path = os.path.join(folder_path, image_file)
    print(f"Processing {image_file}...")
    detect_faces(image_path)

# %%
import os

# Folder containing images
folder_path = r"C:\Users\kalpana\Downloads\extracted_images"  # Update with your path

# List all image files in the folder
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))]

# Detect faces in each image
for image_file in image_files:
    image_path = os.path.join(folder_path, image_file)
    print(f"Processing {image_file}...")
    detect_multiple_faces(image_path)

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Load the pre-trained Haar Cascade for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def detect_multiple_faces(image_path):
    # Load the image from file
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to load image {image_path}")
        return

    # Convert to grayscale for better face detection performance
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces using the Haar cascade (adjust parameters for better results)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=3, minSize=(30, 30))

    # Check if faces were detected
    if len(faces) == 0:
        print("No faces detected!")
    else:
        print(f"Detected {len(faces)} face(s)")

    # Draw rectangles around the faces detected
    for (x, y, w, h) in faces:
        # Draw a green rectangle around each face
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Convert the image from BGR to RGB for display with Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the image with detected faces
    plt.imshow(img_rgb)
    plt.axis('off')  # Hide the axes
    plt.show()

    # Print the positions of each face
    for i, (x, y, w, h) in enumerate(faces):
        print(f"Face {i + 1}: (x: {x}, y: {y}, width: {w}, height: {h})")

# Folder containing images (make sure you update this path)
folder_path = r"C:\\Users\\kalpana\\Downloads\\extracted_images"  # Update with your path

# List all image files in the folder
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))]

# Detect faces in each image
for image_file in image_files:
    image_path = os.path.join(folder_path, image_file)
    print(f"Processing {image_file}...")
    detect_multiple_faces(image_path)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

if face_cascade.empty():
    print("Error: Haar Cascade not loaded correctly!")
else:
    print("Haar Cascade loaded successfully.")
# Out:
# Haar Cascade loaded successfully.

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Load the pre-trained Haar Cascade for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def detect_multiple_faces(image_path):
    # Load the image from file
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to load image {image_path}")
        return

    # Convert to grayscale for better face detection performance
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces using the Haar cascade (adjust parameters for better results)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=3, minSize=(50, 50))

    # Check if faces were detected
    if len(faces) == 0:
        print("No faces detected!")
    else:
        print(f"Detected {len(faces)} face(s)")

    # Draw rectangles around the faces detected
    for (x, y, w, h) in faces:
        # Draw a green rectangle around each face
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Convert the image from BGR to RGB for display with Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the image with detected faces
    plt.imshow(img_rgb)
    plt.axis('off')  # Hide the axes
    plt.show()

    # Print the positions of each face
    for i, (x, y, w, h) in enumerate(faces):
        print(f"Face {i + 1}: (x: {x}, y: {y}, width: {w}, height: {h})")

# Folder containing images (make sure you update this path)
folder_path = r"C:\Users\kalpana\Downloads\extracted_images"  # Update with your path

# List all image files in the folder
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))]

# Detect faces in each image
for image_file in image_files:
    image_path = os.path.join(folder_path, image_file)
    print(f"Processing {image_file}...")
    detect_multiple_faces(image_path)

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the pre-trained DNN model for face detection
net = cv2.dnn.readNetFromCaffe(
    'deploy.prototxt',  # Path to the prototxt file
    'res10_300x300_ssd_iter_140000_fp16.caffemodel'  # Path to the caffemodel file
)

def detect_multiple_faces_dnn(image_path):
    # Load the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to load image {image_path}")
        return

    # Get image height and width
    (h, w) = img.shape[:2]

    # Prepare the image for DNN model
    blob = cv2.dnn.blobFromImage(cv2.resize(img, (300, 300)), 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=True, crop=False)

    # Pass the image through the network
    net.setInput(blob)
    detections = net.forward()

    # List faces detected
    faces = "C:\\Users\\kalpana\\Downloads\\faces.csv"
    
    # Loop over detections and draw rectangles around faces
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]  # Confidence score for the detection
        if confidence > 0.5:  # Confidence threshold
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            faces.append((startX, startY, endX - startX, endY - startY))

            # Draw rectangle around the face
            cv2.rectangle(img, (startX, startY), (endX, endY), (0, 255, 0), 2)

    # Display the image with detected faces
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.show()

    if len(faces) == 0:
        print("No faces detected!")
    else:
        print(f"Detected {len(faces)} face(s):")
        for i, (x, y, w, h) in enumerate(faces):
            print(f"Face {i + 1}: (x: {x}, y: {y}, width: {w}, height: {h})")

# Folder containing images (make sure you update this path)
folder_path = r"C:\Users\kalpana\Downloads\extracted_images"  # Update with your path

# List all image files in the folder
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))]

# Detect faces in each image
for image_file in image_files:
    image_path = os.path.join(folder_path, image_file)
    print(f"Processing {image_file}...")
    detect_multiple_faces_dnn(image_path)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[36], line 7
#       4 import matplotlib.pyplot as plt
#       6 # Load the pre-trained DNN model for face detection
# ----> 7 net = cv2.dnn.readNetFromCaffe(
#       8     'deploy.prototxt',  # Path to the prototxt file
#       9     'res10_300x300_ssd_iter_140000_fp16.caffemodel'  # Path to the caffemodel file
#      10 )
#      12 def detect_multiple_faces_dnn(image_path):
#      13     # Load the image
#      14     img = cv2.imread(image_path)
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\caffe\caffe_io.cpp:1126: error: (-2:Unspecified error) FAILED: fs.is_open(). Can't open "deploy.prototxt" in function 'cv::dnn::ReadProtoFromTextFile'

# %%
net = cv2.dnn.readNetFromCaffe(
    'C:/path_to_files/deploy.prototxt',  # Correct path to the prototxt file
    'C:/path_to_files/res10_300x300_ssd_iter_140000_fp16.caffemodel'  # Correct path to the caffemodel file
)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 net = cv2.dnn.readNetFromCaffe(
#       2     'C:/path_to_files/deploy.prototxt',  # Correct path to the prototxt file
#       3     'C:/path_to_files/res10_300x300_ssd_iter_140000_fp16.caffemodel'  # Correct path to the caffemodel file
#       4 )
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\caffe\caffe_io.cpp:1126: error: (-2:Unspecified error) FAILED: fs.is_open(). Can't open "C:/path_to_files/deploy.prototxt" in function 'cv::dnn::ReadProtoFromTextFile'

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Load the pre-trained DNN model for face detection
prototxt_path = r'C:/models/deploy.prototxt'  # Update this path to where your deploy.prototxt file is located
caffemodel_path = r'C:/models/res10_300x300_ssd_iter_140000_fp16.caffemodel'  # Update this path to where your caffemodel file is located

# Load the network
net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

def detect_multiple_faces_dnn(image_path):
    # Read the image
    img = cv2.imread(image_path)
    
    if img is None:
        print("Error: Failed to read the image!")
        return
    
    # Prepare the image for the DNN
    h, w = img.shape[:2]
    blob = cv2.dnn.blobFromImage(img, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)
    net.setInput(blob)
    detections = net.forward()

    # List to store face rectangles
    faces = []
    
    # Iterate through detections
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        
        if confidence > 0.5:  # Confidence threshold for face detection
            # Get the coordinates of the bounding box
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            faces.append((startX, startY, endX, endY))
    
    return faces, img

def draw_faces_on_image(faces, img):
    # Draw bounding boxes around the faces
    for (startX, startY, endX, endY) in faces:
        cv2.rectangle(img, (startX, startY), (endX, endY), (0, 255, 0), 2)
    
    # Convert the image from BGR to RGB (for displaying with matplotlib)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.axis("off")
    plt.show()

# Path to the folder containing your images (update with your actual folder path)
image_folder = r"C:\\Users\\kalpana\\Downloads\\extracted_images"  # Update this path

# Get all image files in the folder
image_files = [f for f in os.listdir(image_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

if not image_files:
    print("No images found in the folder!")
else:
    for image_file in image_files:
        image_path = os.path.join(image_folder, image_file)
        
        print(f"Processing {image_file}...")
        
        faces, img = detect_multiple_faces_dnn(image_path)
        
        if faces:
            print(f"Found {len(faces)} face(s) in {image_file}")
            draw_faces_on_image(faces, img)
        else:
            print(f"No faces detected in {image_file}")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[37], line 10
#       7 caffemodel_path = r'C:/models/res10_300x300_ssd_iter_140000_fp16.caffemodel'  # Update this path to where your caffemodel file is located
#       9 # Load the network
# ---> 10 net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)
#      12 def detect_multiple_faces_dnn(image_path):
#      13     # Read the image
#      14     img = cv2.imread(image_path)
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\caffe\caffe_io.cpp:1126: error: (-2:Unspecified error) FAILED: fs.is_open(). Can't open "C:/models/deploy.prototxt" in function 'cv::dnn::ReadProtoFromTextFile'

# %%
import os

prototxt_path = r'C:/models/deploy.prototxt'  # Update this path to where your deploy.prototxt file is located
caffemodel_path = r'C:/models/res10_300x300_ssd_iter_140000_fp16.caffemodel'  # Update this path to where your caffemodel file is located

# Check if the files exist
if not os.path.exists(prototxt_path):
    print(f"Error: deploy.prototxt file not found at {prototxt_path}")
else:
    print(f"deploy.prototxt file found at {prototxt_path}")

if not os.path.exists(caffemodel_path):
    print(f"Error: res10_300x300_ssd_iter_140000_fp16.caffemodel file not found at {caffemodel_path}")
else:
    print(f"res10_300x300_ssd_iter_140000_fp16.caffemodel file found at {caffemodel_path}")
# Out:
# Error: deploy.prototxt file not found at C:/models/deploy.prototxt
# Error: res10_300x300_ssd_iter_140000_fp16.caffemodel file not found at C:/models/res10_300x300_ssd_iter_140000_fp16.caffemodel

# %%
prototxt_path = r'C:/models/deploy.prototxt'  # Path to deploy.prototxt
caffemodel_path = r'C:/models/res10_300x300_ssd_iter_140000_fp16.caffemodel'  # Path to res10_300x300_ssd_iter_140000_fp16.caffemodel

# %%
import os

# Define the paths to the files
prototxt_path = r'C:/models/deploy.prototxt'  # Update with the correct folder path
caffemodel_path = r'C:/models/res10_300x300_ssd_iter_140000_fp16.caffemodel'  # Update with the correct folder path

# Check if the files exist
if os.path.exists(prototxt_path):
    print(f"deploy.prototxt file found at {prototxt_path}")
else:
    print(f"Error: deploy.prototxt file not found at {prototxt_path}")

if os.path.exists(caffemodel_path):
    print(f"res10_300x300_ssd_iter_140000_fp16.caffemodel file found at {caffemodel_path}")
else:
    print(f"Error: res10_300x300_ssd_iter_140000_fp16.caffemodel file not found at {caffemodel_path}")
# Out:
# Error: deploy.prototxt file not found at C:/models/deploy.prototxt
# Error: res10_300x300_ssd_iter_140000_fp16.caffemodel file not found at C:/models/res10_300x300_ssd_iter_140000_fp16.caffemodel

# %%
import os

# Define paths to the files
prototxt_path = r"C:\\Users\\kalpana\\Downloads\\deploy.prototxt"  # Ensure the file is in this location
caffemodel_path = r"C:\\Users\\kalpana\\Downloads\\res10_300x300_ssd_iter_140000_fp16.caffemodel"  # Ensure the file is in this location

# Verify the files exist
if os.path.exists(prototxt_path):
    print(f"File found: {prototxt_path}")
else:
    print(f"Error: deploy.prototxt not found at {prototxt_path}")

if os.path.exists(caffemodel_path):
    print(f"File found: {caffemodel_path}")
else:
    print(f"Error: res10_300x300_ssd_iter_140000_fp16.caffemodel not found at {caffemodel_path}")
# Out:
# File found: C:\\Users\\kalpana\\Downloads\\deploy.prototxt
# File found: C:\\Users\\kalpana\\Downloads\\res10_300x300_ssd_iter_140000_fp16.caffemodel

# %%
prototxt_path = r"C:\\Users\\kalpana\\Downloads\\deploy.prototxt"
caffemodel_path = r"C:\\Users\\kalpana\\Downloads\\res10_300x300_ssd_iter_140000_fp16.caffemodel"

net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Paths to the model files (update this based on where you saved the files)
prototxt_path = r"C:\\Users\\kalpana\\Downloads\\deploy.prototxt"  # Update with your path
caffemodel_path = r"C:\\Users\\kalpana\\Downloads\\res10_300x300_ssd_iter_140000_fp16.caffemodel"  # Update with your path

# Check if the model files exist
if not os.path.exists(prototxt_path):
    print(f"Error: deploy.prototxt not found at {prototxt_path}")
elif not os.path.exists(caffemodel_path):
    print(f"Error: res10_300x300_ssd_iter_140000_fp16.caffemodel not found at {caffemodel_path}")
else:
    # Load the pre-trained DNN model for face detection
    net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

    def detect_faces(image_path):
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Error: Unable to read image at {image_path}")
            return

        # Get the image height and width
        (h, w) = image.shape[:2]

        # Prepare the image for the DNN model
        blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)

        # Set the input for the network
        net.setInput(blob)

        # Perform the forward pass and get the detections
        detections = net.forward()

        # Loop over the detections and draw bounding boxes
        for i in range(detections.shape[2]):
            confidence = detections[0, 0, i, 2]  # Confidence score for the detected face
            if confidence > 0.5:  # Only consider faces with a confidence above 50%
                box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
                (startX, startY, endX, endY) = box.astype("int")
                cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)

        # Display the image with the detected faces
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()

    # Test the face detection on an example image (replace 'image_path' with your actual image path)
    image_path = r"C:\\Users\\kalpana\\Downloads\\images-20250217T092357Z-001.zip"  # Update this path to your image file
    detect_faces(image_path)
# Out:
# Error: Unable to read image at C:\\Users\\kalpana\\Downloads\\images-20250217T092357Z-001.zip

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Paths to the model files (update this based on where you saved the files)
prototxt_path = r"C:\\Users\\kalpana\\Downloads\\deploy.prototxt"  # Update with your path
caffemodel_path = r"C:\\Users\\kalpana\\Downloads\\res10_300x300_ssd_iter_140000_fp16.caffemodel"  # Update with your path

# Check if the model files exist
if not os.path.exists(prototxt_path):
    print(f"Error: deploy.prototxt not found at {prototxt_path}")
elif not os.path.exists(caffemodel_path):
    print(f"Error: res10_300x300_ssd_iter_140000_fp16.caffemodel not found at {caffemodel_path}")
else:
    # Load the pre-trained DNN model for face detection
    net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

    def detect_faces(image_path):
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Error: Unable to read image at {image_path}")
            return

        # Get the image height and width
        (h, w) = image.shape[:2]

        # Prepare the image for the DNN model
        blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)

        # Set the input for the network
        net.setInput(blob)

        # Perform the forward pass and get the detections
        detections = net.forward()

        # Loop over the detections and draw bounding boxes
        for i in range(detections.shape[2]):
            confidence = detections[0, 0, i, 2]  # Confidence score for the detected face
            if confidence > 0.5:  # Only consider faces with a confidence above 50%
                box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
                (startX, startY, endX, endY) = box.astype("int")
                cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)

        # Display the image with the detected faces
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()

    # Test the face detection on an example image (replace 'image_path' with your actual image path)
    image_path = r"C:\\Users\\kalpana\\Downloads\\images-20250217T092357Z-001.zip"  # Update this path to your image file
    detect_faces(image_path)
# Out:
# Error: Unable to read image at C:\\Users\\kalpana\\Downloads\\images-20250217T092357Z-001.zip

# %%
import zipfile
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Path to the ZIP file and the folder to extract images to
zip_file_path = r"C:\Users\kalpana\Downloads\images-20250217T092357Z-001.zip"
extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# Step 1: Extract the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder)

# Step 2: Check if extraction was successful
extracted_files = os.listdir(extracted_folder)
print("Extracted files:", extracted_files)

# If no files are extracted, raise an error
if not extracted_files:
    print("Error: No image files found in the extracted folder!")
else:
    # Step 3: Paths to the model files (update these paths if needed)
    prototxt_path = r"C:\\Users\\kalpana\\Downloads\\deploy.prototxt"  # Update with your path
    caffemodel_path = r"C:\\Users\\kalpana\\Downloads\\res10_300x300_ssd_iter_140000_fp16.caffemodel"   # Update with your path

    # Check if the model files exist
    if not os.path.exists(prototxt_path):
        print(f"Error: deploy.prototxt not found at {prototxt_path}")
    elif not os.path.exists(caffemodel_path):
        print(f"Error: res10_300x300_ssd_iter_140000_fp16.caffemodel not found at {caffemodel_path}")
    else:
        # Load the pre-trained DNN model for face detection
        net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

        def detect_faces(image_path):
            # Read the image
            image = cv2.imread(image_path)
            if image is None:
                print(f"Error: Unable to read image at {image_path}")
                return

            # Get the image height and width
            (h, w) = image.shape[:2]

            # Prepare the image for the DNN model
            blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)

            # Set the input for the network
            net.setInput(blob)

            # Perform the forward pass and get the detections
            detections = net.forward()

            # Loop over the detections and draw bounding boxes
            for i in range(detections.shape[2]):
                confidence = detections[0, 0, i, 2]  # Confidence score for the detected face
                if confidence > 0.5:  # Only consider faces with a confidence above 50%
                    box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
                    (startX, startY, endX, endY) = box.astype("int")
                    cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)

            # Display the image with the detected faces
            plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            plt.axis('off')
            plt.show()

        # Step 4: Perform face detection on all extracted images
        for image_file in extracted_files:
            image_path = os.path.join(extracted_folder, image_file)
            detect_faces(image_path)
# Out:
# Extracted files: ['images']
# Error: Unable to read image at C:\Users\kalpana\Downloads\extracted_images\images

# %%
import zipfile
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Path to the ZIP file and the folder to extract images to
zip_file_path = r"C:\Users\kalpana\Downloads\images-20250217T092357Z-001.zip"
extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# Step 1: Extract the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder)

# Step 2: Check if extraction was successful
extracted_files = os.listdir(extracted_folder)
print("Extracted files:", extracted_files)

# If no files are extracted, raise an error
if not extracted_files:
    print("Error: No image files found in the extracted folder!")
else:
    # Step 3: Paths to the model files (update these paths if needed)
    prototxt_path = r"C:\\Users\\kalpana\\Downloads\\deploy.prototxt"  # Update with your path
    caffemodel_path = r"C:\\Users\\kalpana\\Downloads\\res10_300x300_ssd_iter_140000_fp16.caffemodel"   # Update with your path

    # Check if the model files exist
    if not os.path.exists(prototxt_path):
        print(f"Error: deploy.prototxt not found at {prototxt_path}")
    elif not os.path.exists(caffemodel_path):
        print(f"Error: res10_300x300_ssd_iter_140000_fp16.caffemodel not found at {caffemodel_path}")
    else:
        # Load the pre-trained DNN model for face detection
        net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

        def detect_faces(image_path):
            # Read the image
            image = cv2.imread(image_path)
            if image is None:
                print(f"Error: Unable to read image at {image_path}")
                return

            # Get the image height and width
            (h, w) = image.shape[:2]

            # Prepare the image for the DNN model
            blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)

            # Set the input for the network
            net.setInput(blob)

            # Perform the forward pass and get the detections
            detections = net.forward()

            # Loop over the detections and draw bounding boxes
            for i in range(detections.shape[2]):
                confidence = detections[0, 0, i, 2]  # Confidence score for the detected face
                if confidence > 0.5:  # Only consider faces with a confidence above 50%
                    box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
                    (startX, startY, endX, endY) = box.astype("int")
                    cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)

            # Display the image with the detected faces
            plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            plt.axis('off')
            plt.show()

        # Step 4: Perform face detection on all extracted images
        for image_file in extracted_files:
            image_path = os.path.join(extracted_folder, image_file)
            detect_faces(image_path)
# Out:
# Extracted files: ['images']
# Error: Unable to read image at C:\Users\kalpana\Downloads\extracted_images\images

# %%
import zipfile
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Path to the ZIP file and the folder to extract images to
zip_file_path = r"C:\Users\kalpana\Downloads\images-20250217T092357Z-001.zip"
extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# Step 1: Extract the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder)

# Step 2: Check if extraction was successful
extracted_files = os.listdir(extracted_folder)
print("Extracted files:", extracted_files)

# If no files are extracted, raise an error
if not extracted_files:
    print("Error: No image files found in the extracted folder!")
else:
    # Step 3: Paths to the model files (update these paths if needed)
    prototxt_path = r"C:\\Users\\kalpana\\Downloads\\deploy.prototxt"  # Update with your path
    caffemodel_path = r"C:\\Users\\kalpana\\Downloads\\res10_300x300_ssd_iter_140000_fp16.caffemodel"   # Update with your path

    # Check if the model files exist
    if not os.path.exists(prototxt_path):
        print(f"Error: deploy.prototxt not found at {prototxt_path}")
    elif not os.path.exists(caffemodel_path):
        print(f"Error: res10_300x300_ssd_iter_140000_fp16.caffemodel not found at {caffemodel_path}")
    else:
        # Load the pre-trained DNN model for face detection
        net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

        def detect_faces(image_path):
            # Read the image
            image = cv2.imread(image_path)
            if image is None:
                print(f"Error: Unable to read image at {image_path}")
                return

            # Get the image height and width
            (h, w) = image.shape[:2]

            # Prepare the image for the DNN model
            blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)

            # Set the input for the network
            net.setInput(blob)

            # Perform the forward pass and get the detections
            detections = net.forward()

            # Loop over the detections and draw bounding boxes
            for i in range(detections.shape[2]):
                confidence = detections[0, 0, i, 2]  # Confidence score for the detected face
                if confidence > 0.5:  # Only consider faces with a confidence above 50%
                    box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
                    (startX, startY, endX, endY) = box.astype("int")
                    cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)

            # Display the image with the detected faces
            plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            plt.axis('off')
            plt.show()

        # Step 4: Perform face detection on all extracted images
        for image_file in extracted_files:
            image_path = os.path.join(extracted_folder, image_file)
            detect_faces(image_path)
# Out:
# Extracted files: ['images']
# Error: Unable to read image at C:\Users\kalpana\Downloads\extracted_images\images

# %%
import os
print(os.listdir(r"C:\Users\kalpana\Downloads\extracted_images\images"))
# Out:
# ['00000003.jpg', '00000004.jpg', '00000005.jpg', '00000006.jpg', '00000008.jpg', '00000011.jpg', '00000012.jpg', '00000015.jpg', '00000018.jpg', '00000020.jpg', '00000022.jpg', '00000023.jpg', '00000024.jpg', '00000026.jpg', '00000031.jpg', '00000032.jpg', '00000041.jpg', '00000044.jpg', '00000045.jpg', '00000047.jpg', '00000050.jpg', '00000051.jpg', '00000055.jpg', '00000058.jpg', '00000061.jpg', '00000067.jpg', '00000068.jpg', '00000069.jpg', '00000072.jpg', '00000074.jpg', '00000075.jpg', '00000077.jpg', '00000082.jpg', '00000085.jpg', '00000086.jpg', '00000087.jpg', '00000088.jpg', '00000089.jpg', '00000091.jpg', '00000094.jpg', '00000095.jpg', '00000097.jpg', '00000099.jpg', '00000100.jpg', '00000103.jpg', '00000104.jpg', '00000105.jpg', '00000107.jpg', '00000110.jpg', '00000114.jpg', '00000115.jpg', '00000118.jpg', '00000119.jpg', '00000120.jpg', '00000123.jpg', '00000127.jpg', '00000128.jpg', '00000129.jpg', '00000135.jpg', '00000136.jpg', '00000137.jpg', '00000138.jpg', '0000
# ...

# %%
extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images\images"

# %%
for image_file in extracted_files:
    image_path = os.path.join(extracted_folder, image_file)
    print("Processing:", image_path)
    detect_faces(image_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for image_file in extracted_files:
#       2     image_path = os.path.join(extracted_folder, image_file)
#       3     print("Processing:", image_path)
#
# NameError: name 'extracted_files' is not defined

# %%
import zipfile
import os

zip_file_path = r"C:\Users\kalpana\Downloads\images-20250217T092357Z-001.zip"
extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images"

# Extract ZIP
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder)

# List extracted files
extracted_files = os.listdir(extracted_folder)
print("Extracted files:", extracted_files)
# Out:
# Extracted files: ['images']

# %%
for file in extracted_files:
    print(file)  # This should print image filenames
# Out:
# images

# %%
for image_file in extracted_files:
    image_path = os.path.join(extracted_folder, image_file)
    print("Processing:", image_path)
    # Ensure detect_faces is defined before calling it
    if 'detect_faces' in globals():
        detect_faces(image_path)
    else:
        print("Error: detect_faces function is not defined.")
# Out:
# Processing: C:\Users\kalpana\Downloads\extracted_images\images
# Error: detect_faces function is not defined.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Load the pre-trained face detection model
prototxt_path = r"C:\Users\kalpana\Downloads\deploy.prototxt"
caffemodel_path = r"C:\Users\kalpana\Downloads\res10_300x300_ssd_iter_140000_fp16.caffemodel"

if not os.path.exists(prototxt_path):
    print(f"Error: deploy.prototxt not found at {prototxt_path}")
elif not os.path.exists(caffemodel_path):
    print(f"Error: res10_300x300_ssd_iter_140000_fp16.caffemodel not found at {caffemodel_path}")
else:
    net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

def detect_faces(image_path):
    """Detect faces in an image using OpenCV DNN model."""
    image = cv2.imread(image_path)

    # Ensure the image was loaded correctly
    if image is None:
        print(f"Error: Unable to read image at {image_path}")
        return

    (h, w) = image.shape[:2]

    # Prepare the image for the DNN model
    blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)
    net.setInput(blob)
    detections = net.forward()

    # Loop over detections and draw bounding boxes
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > 0.5:
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)

    # Display the image
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

# %%
if 'detect_faces' in globals():
    print("detect_faces function is properly defined!")
else:
    print("Error: detect_faces function is missing.")
# Out:
# detect_faces function is properly defined!

# %%
extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images"
extracted_files = os.listdir(extracted_folder)

for image_file in extracted_files:
    image_path = os.path.join(extracted_folder, image_file)
    print("Processing:", image_path)

    if 'detect_faces' in globals():
        detect_faces(image_path)
    else:
        print("Error: detect_faces function is not defined.")
# Out:
# Processing: C:\Users\kalpana\Downloads\extracted_images\images
# Error: Unable to read image at C:\Users\kalpana\Downloads\extracted_images\images

# %%
import os

extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images"
extracted_files = os.listdir(extracted_folder)

print("Extracted files and folders:", extracted_files)
# Out:
# Extracted files and folders: ['images']

# %%
import os

extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images\images"  # Updated path
extracted_files = os.listdir(extracted_folder)

print("Updated extracted files:", extracted_files)  # Should list image files

for image_file in extracted_files:
    image_path = os.path.join(extracted_folder, image_file)

    # Ensure it's an image before processing
    if image_file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
        print("Processing:", image_path)
        detect_faces(image_path)
    else:
        print(f"Skipping non-image file: {image_file}")
# Out:
# Updated extracted files: ['00000003.jpg', '00000004.jpg', '00000005.jpg', '00000006.jpg', '00000008.jpg', '00000011.jpg', '00000012.jpg', '00000015.jpg', '00000018.jpg', '00000020.jpg', '00000022.jpg', '00000023.jpg', '00000024.jpg', '00000026.jpg', '00000031.jpg', '00000032.jpg', '00000041.jpg', '00000044.jpg', '00000045.jpg', '00000047.jpg', '00000050.jpg', '00000051.jpg', '00000055.jpg', '00000058.jpg', '00000061.jpg', '00000067.jpg', '00000068.jpg', '00000069.jpg', '00000072.jpg', '00000074.jpg', '00000075.jpg', '00000077.jpg', '00000082.jpg', '00000085.jpg', '00000086.jpg', '00000087.jpg', '00000088.jpg', '00000089.jpg', '00000091.jpg', '00000094.jpg', '00000095.jpg', '00000097.jpg', '00000099.jpg', '00000100.jpg', '00000103.jpg', '00000104.jpg', '00000105.jpg', '00000107.jpg', '00000110.jpg', '00000114.jpg', '00000115.jpg', '00000118.jpg', '00000119.jpg', '00000120.jpg', '00000123.jpg', '00000127.jpg', '00000128.jpg', '00000129.jpg', '00000135.jpg', '00000136.jpg', '00000137.jp
# ...

# %%
import cv2

test_image_path = os.path.join(extracted_folder, extracted_files[0])  # Pick first image
test_image = cv2.imread(test_image_path)

if test_image is None:
    print("Error: Unable to read the test image. Check file format or corruption.")
else:
    print("Test image loaded successfully!")
# Out:
# Test image loaded successfully!

# %%
import cv2
import numpy as np
import os

# Define the paths for saving detected faces
detected_faces_folder = r"C:\Users\kalpana\Downloads\detected_faces"

# Create folder if it does not exist
if not os.path.exists(detected_faces_folder):
    os.makedirs(detected_faces_folder)

def detect_faces(image_path):
    """Detect faces in an image, save cropped face images, and display results."""
    image = cv2.imread(image_path)

    if image is None:
        print(f"Error: Unable to read image at {image_path}")
        return

    (h, w) = image.shape[:2]

    # Prepare image for DNN model
    blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)
    net.setInput(blob)
    detections = net.forward()

    face_count = 0  # Counter for multiple faces

    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]

        if confidence > 0.5:  # Confidence threshold
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # Crop the detected face
            face = image[startY:endY, startX:endX]

            if face.size > 0:  # Ensure valid face region
                # Save the cropped face image
                face_filename = os.path.join(detected_faces_folder, f"face_{face_count}.jpg")
                cv2.imwrite(face_filename, face)
                print(f"Face {face_count} saved at {face_filename}")

                # Show the cropped face (optional)
                cv2.imshow(f"Face {face_count}", face)
                cv2.waitKey(500)  # Display for 500ms (adjust as needed)

                face_count += 1  # Increment face counter

            # Draw bounding box on original image
            cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)

    # Show the original image with bounding boxes
    cv2.imshow("Detected Faces", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
for image_file in extracted_files:
    image_path = os.path.join(extracted_folder, image_file)
    detect_faces(image_path)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[14], line 3
#       1 for image_file in extracted_files:
#       2     image_path = os.path.join(extracted_folder, image_file)
# ----> 3     detect_faces(image_path)
#
# Cell In[13], line 25, in detect_faces(image_path)
#      23 blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)
#      24 net.setInput(blob)
# ---> 25 detections = net.forward()
#      27 face_count = 0  # Counter for multiple faces
#      29 for i in range(detections.shape[2]):
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\layers\convolution_layer.cpp:368: error: (-215:Assertion failed) !blobs.empty() || inputs.size() > 1 in function 'cv::dnn::ConvolutionLayerImpl::getMemoryShapes'

# %%
import os

prototxt_path = r"C:\Users\kalpana\Downloads\deploy.prototxt"
caffemodel_path = r"C:\Users\kalpana\Downloads\res10_300x300_ssd_iter_140000_fp16.caffemodel"

if not os.path.exists(prototxt_path):
    print(f"Error: deploy.prototxt not found at {prototxt_path}")

if not os.path.exists(caffemodel_path):
    print(f"Error: res10_300x300_ssd_iter_140000_fp16.caffemodel not found at {caffemodel_path}")

# Try loading the model
try:
    net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)
    print("Model loaded successfully!")
except Exception as e:
    print(f"Error loading model: {e}")
# Out:
# Model loaded successfully!

# %%
import cv2

for image_file in extracted_files:
    image_path = os.path.join(extracted_folder, image_file)
    image = cv2.imread(image_path)

    if image is None:
        print(f"Error: Unable to read {image_path}")
    else:
        print(f"Successfully loaded: {image_path}")
# Out:
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000003.jpg
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000004.jpg
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000005.jpg
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000006.jpg
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000008.jpg
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000011.jpg
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000012.jpg
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000015.jpg
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000018.jpg
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000020.jpg
# Successfully loaded: C:\Users\kalpana\Downloads\extracted_images\images\00000022.jpg
# ...

# %%
def detect_faces(image_path):
    """Detect faces in an image using OpenCV DNN model."""
    image = cv2.imread(image_path)

    if image is None:
        print(f"Error: Unable to read image at {image_path}")
        return

    # Reload model inside the function
    net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

    (h, w) = image.shape[:2]
    blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)
    net.setInput(blob)
    detections = net.forward()

    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > 0.5:
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)

    cv2.imshow("Detected Faces", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
def detect_faces(image_path):
    """Detect faces in an image and print how many were found."""
    image = cv2.imread(image_path)

    if image is None:
        print(f"❌ Error: Unable to read image at {image_path}")
        return

    # Reload model
    net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

    (h, w) = image.shape[:2]
    blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)
    net.setInput(blob)
    detections = net.forward()

    face_count = 0  # Count faces detected

    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]

        if confidence > 0.5:  # Only consider confident detections
            face_count += 1

    print(f"✅ Processed {image_path}: {face_count} face(s) detected.")

    if face_count == 0:
        print("⚠️ No faces detected in this image.")

# Run face detection on all images
for image_file in extracted_files:
    image_path = os.path.join(extracted_folder, image_file)
    detect_faces(image_path)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 33
#      31 for image_file in extracted_files:
#      32     image_path = os.path.join(extracted_folder, image_file)
# ---> 33     detect_faces(image_path)
#
# Cell In[18], line 15, in detect_faces(image_path)
#      13 blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)
#      14 net.setInput(blob)
# ---> 15 detections = net.forward()
#      17 face_count = 0  # Count faces detected
#      19 for i in range(detections.shape[2]):
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\layers\convolution_layer.cpp:368: error: (-215:Assertion failed) !blobs.empty() || inputs.size() > 1 in function 'cv::dnn::ConvolutionLayerImpl::getMemoryShapes'

# %%
def detect_faces(image_path):
    """Detect faces in an image and handle possible errors."""
    image = cv2.imread(image_path)

    if image is None:
        print(f"❌ Error: Unable to read image at {image_path}")
        return  # Skip processing this image

    print(f"✅ Loaded image: {image_path}")

    net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

    (h, w) = image.shape[:2]
    blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)

    if blob is None:
        print(f"⚠️ Warning: Blob creation failed for {image_path}")
        return

    net.setInput(blob)
    detections = net.forward()

    face_count = 0  # Count faces detected

    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]

        if confidence > 0.5:
            print(f"✅ Face detected with confidence {confidence:.2f}")

            # Get bounding box coordinates
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # Crop and save the face
            face = image[startY:endY, startX:endX]

            if face.shape[0] > 0 and face.shape[1] > 0:
                face_filename = os.path.join(detected_faces_folder, f"face_{face_count}.jpg")
                cv2.imwrite(face_filename, face)
                print(f"✅ Face {face_count} saved at {face_filename}")
                face_count += 1

    if face_count == 0:
        print("⚠️ No faces detected.")

# Run face detection on all images
for image_file in extracted_files:
    image_path = os.path.join(extracted_folder, image_file)
    detect_faces(image_path)
# Out:
# ✅ Loaded image: C:\Users\kalpana\Downloads\extracted_images\images\00000003.jpg
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[19], line 50
#      48 for image_file in extracted_files:
#      49     image_path = os.path.join(extracted_folder, image_file)
# ---> 50     detect_faces(image_path)
#
# Cell In[19], line 21, in detect_faces(image_path)
#      18     return
#      20 net.setInput(blob)
# ---> 21 detections = net.forward()
#      23 face_count = 0  # Count faces detected
#      25 for i in range(detections.shape[2]):
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\layers\convolution_layer.cpp:368: error: (-215:Assertion failed) !blobs.empty() || inputs.size() > 1 in function 'cv::dnn::ConvolutionLayerImpl::getMemoryShapes'

# %%
if not os.path.exists(prototxt_path):
    print(f"❌ Error: prototxt file not found at {prototxt_path}")
if not os.path.exists(caffemodel_path):
    print(f"❌ Error: Caffe model not found at {caffemodel_path}")

# %%
def detect_faces(image_path):
    image = cv2.imread(image_path)
    
    if image is None:
        print(f"❌ Error: Unable to read image at {image_path}")
        return
    
    print(f"✅ Loaded image: {image_path}")
    
    # Load model again to ensure it's available
    net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

    # Get image dimensions
    (h, w) = image.shape[:2]

    # Create a blob from the image
    blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)

    # **Check if the blob is empty**
    if blob is None or blob.shape[2] == 0 or blob.shape[3] == 0:
        print(f"⚠️ Warning: Blob creation failed for {image_path}")
        return

    net.setInput(blob)
    
    try:
        detections = net.forward()  # Run face detection
    except Exception as e:
        print(f"❌ Error during forward pass: {e}")
        return

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Paths to the model files (update these paths as needed)
prototxt_path = r"C:\Users\kalpana\OneDrive\Documents\deploy.prototxt.txt" # Replace with your path
caffemodel_path = r"C:\Users\kalpana\Downloads\res10_300x300_ssd_iter_140000.caffemodel"  # Replace with your path

# Load the pre-trained model
net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

def detect_faces(image_path):
    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Unable to read image at {image_path}")
        return

    # Get the image height and width
    (h, w) = image.shape[:2]

    # Prepare the image for the DNN model
    blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)

    # Set the input for the network
    net.setInput(blob)

    # Perform the forward pass and get the detections
    detections = net.forward()

    # Loop over the detections and draw bounding boxes
    face_count = 0
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]  # Confidence score for the detected face
        if confidence > 0.5:  # Only consider faces with a confidence above 50%
            # Get the bounding box coordinates
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            
            # Draw the bounding box around the face
            cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)
            face_count += 1

    # Display the image with the detected faces
    print(f"Detected {face_count} faces in {image_path}")
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

    # Optionally, save the image with detected faces
    output_path = os.path.join("detected_faces", os.path.basename(image_path))
    cv2.imwrite(output_path, image)
    print(f"Saved image with faces: {output_path}")

# Example of how to use the function on a folder of images
extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images"
extracted_files = os.listdir(extracted_folder)

# Ensure the 'detected_faces' folder exists for saving output images
os.makedirs("detected_faces", exist_ok=True)

# Loop through all extracted images and perform face detection
for image_file in extracted_files:
    image_path = os.path.join(extracted_folder, image_file)
    print(f"Processing {image_path}...")
    detect_faces(image_path)
# Out:
# Processing C:\Users\kalpana\Downloads\extracted_images\images...
# Error: Unable to read image at C:\Users\kalpana\Downloads\extracted_images\images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Paths to the model files (update these paths as needed)
prototxt_path = r"C:\Users\kalpana\OneDrive\Documents\deploy.prototxt.txt"  # Replace with your path
caffemodel_path = r"C:\Users\kalpana\Downloads\res10_300x300_ssd_iter_140000.caffemodel"  # Replace with your path

# Load the pre-trained model
net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)

def detect_faces(image_path):
    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Unable to read image at {image_path}")
        return

    # Get the image height and width
    (h, w) = image.shape[:2]

    # Prepare the image for the DNN model
    blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)

    # Set the input for the network
    net.setInput(blob)

    # Perform the forward pass and get the detections
    detections = net.forward()

    # Loop over the detections and draw bounding boxes
    face_count = 0
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]  # Confidence score for the detected face
        if confidence > 0.5:  # Only consider faces with a confidence above 50%
            # Get the bounding box coordinates
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            
            # Draw the bounding box around the face
            cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)
            face_count += 1

    # Display the image with the detected faces
    print(f"Detected {face_count} faces in {image_path}")
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

    # Optionally, save the image with detected faces
    output_path = os.path.join("detected_faces", os.path.basename(image_path))
    cv2.imwrite(output_path, image)
    print(f"Saved image with faces: {output_path}")

# Example of how to use the function on a folder of images
extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images"
extracted_files = os.listdir(extracted_folder)

# Ensure the 'detected_faces' folder exists for saving output images
os.makedirs("detected_faces", exist_ok=True)

# Loop through all extracted images and perform face detection
for image_file in extracted_files:
    image_path = os.path.join(extracted_folder, image_file)
    
    # Check if the file is an image (you can add more extensions as needed)
    if image_file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff')):
        print(f"Processing {image_path}...")
        detect_faces(image_path)
    else:
        print(f"Skipping non-image file: {image_path}")
# Out:
# Skipping non-image file: C:\Users\kalpana\Downloads\extracted_images\images

# %% [markdown]
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# import os
#
# # Paths to the model files (update these paths as needed)
# prototxt_path = r"C:\Users\kalpana\OneDrive\Documents\deploy.prototxt.txt"  # Replace with your path
# caffemodel_path = r"C:\Users\kalpana\Downloads\res10_300x300_ssd_iter_140000.caffemodel"  # Replace with your path
#
# # Load the pre-trained model
# net = cv2.dnn.readNetFromCaffe(prototxt_path, caffemodel_path)
#
# def detect_faces(image_path):
#     # Read the image
#     image = cv2.imread(image_path)
#     if image is None:
#         print(f"Error: Unable to read image at {image_path}")
#         return
#
#     # Get the image height and width
#     (h, w) = image.shape[:2]
#
#     # Prepare the image for the DNN model
#     blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)
#
#     # Set the input for the network
#     net.setInput(blob)
#
#     # Perform the forward pass and get the detections
#     detections = net.forward()
#
#     # Loop over the detections and draw bounding boxes
#     face_count = 0
#     for i in range(detections.shape[2]):
#         confidence = detections[0, 0, i, 2]  # Confidence score for the detected face
#         if confidence > 0.5:  # Only consider faces with a confidence above 50%
#             # Get the bounding box coordinates
#             box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
#             (startX, startY, endX, endY) = box.astype("int")
#
#             # Draw the bounding box around the face
#             cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)
#             face_count += 1
#
#     # Display the image with the detected faces
#     print(f"Detected {face_count} faces in {image_path}")
#     plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#     plt.axis('off')
#     plt.show()
#
#     # Optionally, save the image with detected faces
#     output_path = os.path.join("detected_faces", os.path.basename(image_path))
#     cv2.imwrite(output_path, image)
#     print(f"Saved image with faces: {output_path}")
#
# # Example of how to use the function on a folder of images
# extracted_folder = r"C:\Users\kalpana\Downloads\extracted_images"
# extracted_files = os.listdir(extracted_folder)
#
# # Ensure the 'detected_faces' folder exists for saving output images
# os.makedirs("detected_faces", exist_ok=True)
#
# # Loop through all extracted files and check if they are directories or images
# for item in extracted_files:
#     item_path = os.path.join(extracted_folder, item)
#
#     # If the item is a directory, process images inside that folder
#     if os.path.isdir(item_path):
#         print(f"Found directory: {item_path}")
#         subfolder_files = os.listdir(item_path)
#
#         for sub_item in subfolder_files:
#             sub_item_path = os.path.join(item_path, sub_item)
#
#             # Check if the file is an image
#             if sub_item.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff')):
#                 print(f"Processing image: {sub_item_path}...")
#                 detect_faces(sub_item_path)
#             else:
#                 print(f"Skipping non-image file: {sub_item_path}")
#
#     # If the item is an image, process it directly
#     elif item.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff')):
#         print(f"Processing image: {item_path}...")
#         detect_faces(item_path)
#     else:
#         print(f"Skipping non-image file: {item_path}")
